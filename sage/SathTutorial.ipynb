# %%
1+1
# Out:
# 2

# %%
57.1^100
# Out:
# 4.60904368661396e175

# %%
matrix([[1,2],[2,3]])^(-1)
# Out:
# [-3  2]
# [ 2 -1]

# %%
x = var('x')
integrate(sqrt(x)*sqrt(1+x), x)
# Out:
# 1/4*((x + 1)^(3/2)/x^(3/2) + sqrt(x + 1)/sqrt(x))/((x + 1)^2/x^2 - 2*(x + 1)/x + 1) - 1/8*log(sqrt(x + 1)/sqrt(x) + 1) + 1/8*log(sqrt(x + 1)/sqrt(x) - 1)

# %%
a = var('a')
S = solve(x^2 + x == a, x); S
# Out:
# [x == -1/2*sqrt(4*a + 1) - 1/2, x == 1/2*sqrt(4*a + 1) - 1/2]

# %%
S[0].rhs()
# Out:
# -1/2*sqrt(4*a + 1) - 1/2

# %%
show(plot(sin(x), 0, 4))
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Graphics object consisting of 1 graphics primitive

# %%
m = random_matrix(RDF, 500)

# %%
e = m.eigenvalues()
w = [(i, abs(e[i])) for i in range(len(e))]
show(points(w))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
factorial(100)
# Out:
# 93326215443944152681699238856266700490715968264381621468592963895217599993229915608941463976156518286253697920827223758251185210916864000000000000000000000000

# %%
n = factorial(1000000)
len(n.digits())
# Out:
# 5565709

# %%
N(pi, digits=100)
# Out:
# 3.141592653589793238462643383279502884197169399375105820974944592307816406286208998628034825342117068

# %%
R.<x,y> = QQ[]

# %%
F = factor(x^99+y^99)

# %%
F
# Out:
# (x + y) * (x^2 - x*y + y^2) * (x^6 - x^3*y^3 + y^6) * (x^10 - x^9*y + x^8*y^2 - x^7*y^3 + x^6*y^4 - x^5*y^5 + x^4*y^6 - x^3*y^7 + x^2*y^8 - x*y^9 + y^10) * (x^20 + x^19*y - x^17*y^3 - x^16*y^4 + x^14*y^6 + x^13*y^7 - x^11*y^9 - x^10*y^10 - x^9*y^11 + x^7*y^13 + x^6*y^14 - x^4*y^16 - x^3*y^17 + x*y^19 + y^20) * (x^60 + x^57*y^3 - x^51*y^9 - x^48*y^12 + x^42*y^18 + x^39*y^21 - x^33*y^27 - x^30*y^30 - x^27*y^33 + x^21*y^39 + x^18*y^42 - x^12*y^48 - x^9*y^51 + x^3*y^57 + y^60)

# %%
F.expand()
# Out:
# x^99 + y^99

# %%
sin(x)._mathematica_init_()
# Out:
# 'Sin[x]'

# %%
print(mathematica(sin(x)))
# Out:
# ---------------------------------------------------------------------------
# EOF                                       Traceback (most recent call last)
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/interfaces/expect.py:543, in Expect._start(self, alt_message, block_during_init)
#     542 try:
# --> 543     self._expect.expect(self._prompt)
#     544 except (pexpect.TIMEOUT, pexpect.EOF) as msg:
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/pexpect/spawnbase.py:354, in SpawnBase.expect(self, pattern, timeout, searchwindowsize, async_, **kw)
#     353 compiled_pattern_list = self.compile_pattern_list(pattern)
# --> 354 return self.expect_list(compiled_pattern_list,
#     355         timeout, searchwindowsize, async_)
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/pexpect/spawnbase.py:383, in SpawnBase.expect_list(self, pattern_list, timeout, searchwindowsize, async_, **kw)
# ...
