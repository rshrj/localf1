# %%
from ore_algebra import OreAlgebra, DifferentialOperators
sage: Pol.<x> = QQ[]
sage: Dop.<Dx> = OreAlgebra(Pol)
sage: QQi.<i> = QuadraticField(-1)

# %%
dop = (x^2+1)*Dx^2 + 2*x*Dx

# %%
dop.indicial_polynomial(x)
# Out:
# alpha^2 - alpha

# %%
dop.local_basis_monomials(i)
# Out:
# [log(x - I), 1]

# %%
dop.numerical_transition_matrix([0, i]).n()._mathematica_init_()
# Out:
# '{{0.0000000000000000, -0.50000000000000000*I}, {1.0000000000000000, 0.78539816339744828 + 0.34657359027997264*I}}'

# %%
dop.numerical_transition_matrix([0, i+1, 2*i, i-1, 0]).n()._mathematica_init_()
# Out:
# '{{1.0000000000000000, 3.1415926535897931 + 2.4815418376590830*^-23*I}, {0.0000000000000000, 1.0000000000000000 - 9.8943776643499800*^-23*I}}'

# %%
from ore_algebra.examples.iint import *

# %%
f[14]
# Out:
# -1/(x - 14)

# %%
dop = diffop([f[1/4], w[1], f[1]])

# %%
dop
# Out:
# (x^5 - 9/4*x^4 + 3/2*x^3 - 1/4*x^2)*Dx^4 + (6*x^4 - 43/4*x^3 + 5*x^2 - 1/4*x)*Dx^3 + (7*x^3 - 35/4*x^2 + 15/8*x + 1/16)*Dx^2 + (x^2 - 1/2*x - 1/4)*Dx

# %%
# ?diffop
# Out:
# Signature:      diffop(word)
# Init docstring: Initialize self.  See help(type(self)) for accurate signature.
# File:           ~/Library/SageMath-10-7/lib/python3.13/site-packages/ore_algebra/examples/iint.py
# Type:           function

# %%
help(diffop)
# Out:
# Help on function diffop in module ore_algebra.examples.iint:
#
# diffop(word)
