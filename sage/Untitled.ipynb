# %%
import sage

# %%
1+1
# Out:
# 2

# %%
RIF(sqrt(2))
# Out:
# 1.414213562373095?

# %%
# %pip install --no-build-isolation git+https://github.com/mkauers/ore_algebra.git
# Out:
# ...
#   Cloning https://github.com/mkauers/ore_algebra.git to /private/var/folders/pc/b7vhpj7927qc42vnqlb75bm40000gn/T/pip-req-build-ylh0fex5
#   Running command git clone --filter=blob:none --quiet https://github.com/mkauers/ore_algebra.git /private/var/folders/pc/b7vhpj7927qc42vnqlb75bm40000gn/T/pip-req-build-ylh0fex5
#   Resolved https://github.com/mkauers/ore_algebra.git to commit b71a0db1c47946fd139c710c0bf4ff0ca510d7fe
#   Preparing metadata (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [118 lines of output]
#
#       Error compiling Cython file:
#       ------------------------------------------------------------
#       ...
#       from sage.libs.mpfr.types cimport mpfr_prec_t
#       from sage.libs.mpfi.types cimport mpfi_t
#       ^
#       ------------------------------------------------------------
#
# ...
